# %%
import snowflake.connector

conn = snowflake.connector.connect(
    account="JDCQRMX-AZ84197",
    user="ATSUKI",
    password="E5NH_2y_Lhw2zQH",
    warehouse="COMPUTE_WH",
    database="SENSOR_LAB",
    schema="BRONZE"
)
cur = conn.cursor()

# %%
cur.execute("SELECT CURRENT_VERSION()")
print(cur.fetchone())
conn.close()
# Out:
# ('10.10.2',)

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    account="JDCQRMX-AZ84197",
    user="ATSUKI",
    password="E5NH_2y_Lhw2zQH",
    warehouse="COMPUTE_WH",
    database="SENSOR_LAB",
    schema="BRONZE"
)
cur = conn.cursor()

# %%
# 1ファイルアップロード
cur.execute("PUT file://sensor\sensor_osaka_20240115.csv @BRONZE_STAGE AUTO_COMPRESS=FALSE")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\atsuk\AppData\Local\Temp\ipykernel_25184\1332067858.py:2: SyntaxWarning: invalid escape sequence '\s'
#   cur.execute("PUT file://sensor\sensor_osaka_20240115.csv @BRONZE_STAGE AUTO_COMPRESS=FALSE")

# %%
# ステージ上のファイル確認
cur.execute("LIST @BRONZE_STAGE")
for row in cur.fetchall():
    print(row)
# Out:
# ('bronze_stage/sensor_osaka_20240115.csv', 22240, 'cdde27b9dd27abdb34017dbaf3cfd18b', 'Sat, 28 Mar 2026 09:33:06 GMT')
# ('bronze_stage/sensor_tokyo_20240115.csv', 22080, 'b53f2ebf256141afc10ff00c6c926d6d', 'Sat, 28 Mar 2026 08:51:36 GMT')
# ('bronze_stage/sensor_tokyo_20240116.csv', 22048, '9d2f400abc0e28991d1f16bc7625dfba', 'Sat, 28 Mar 2026 08:56:53 GMT')

# %%
conn.close()
